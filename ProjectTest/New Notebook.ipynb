# %%
import arcpy

# %%
import os
os.path.abspath('')
# Out:
# 'C:\\Users\\karimb\\Documents\\GitHub\\python-kurs-test\\ProjectTest'

# %%
desc = arcpy.Describe()
desc
# Out:
# <geoprocessing describe data object object at 0x000001FC8CC37770>

# %%
path = 'data/GEDEvent_v23_0_9.csv'
table = arcpy.management.MakeTableView(path, 'tableview')
print(table)
fields = arcpy.ListFields(table)
fieldnames = [f.name for f in fields]
print(fieldnames)
# Out:
# tableview
# ['id', 'relid', 'year', 'active_year', 'code_status', 'type_of_violence', 'conflict_dset_id', 'conflict_new_id', 'conflict_name', 'dyad_dset_id', 'dyad_new_id', 'dyad_name', 'side_a_dset_id', 'side_a_new_id', 'side_a', 'side_b_dset_id', 'side_b_new_id', 'side_b', 'number_of_sources', 'source_article', 'source_office', 'source_date', 'source_headline', 'source_original', 'where_prec', 'where_coordinates', 'where_description', 'adm_1', 'adm_2', 'latitude', 'longitude', 'geom_wkt', 'priogrid_gid', 'country', 'country_id', 'region', 'event_clarity', 'date_prec', 'date_start', 'date_end', 'deaths_a', 'deaths_b', 'deaths_civilians', 'deaths_unknown', 'best', 'high', 'low', 'gwnoa', 'gwnob']

# %%
from pprint import pprint
with arcpy.da.SearchCursor(table, ['*']) as search:
    for row in search:
        rowdict = {field:value for field,value in zip(fieldnames,row)}
        pprint(rowdict)
        fdsfsdfds
# Out:
# {'active_year': 'true',
#  'adm_1': 'Balkh province',
#  'adm_2': 'Mazari Sharif district',
#  'best': 2,
#  'code_status': 'Clear',
#  'conflict_dset_id': '130',
#  'conflict_name': 'Government of Afghanistan - Civilians',
#  'conflict_new_id': 484,
#  'country': 'Afghanistan',
#  'country_id': 700,
#  'date_end': '2023-09-07 00:00:00.000',
#  'date_prec': 1,
#  'date_start': '2023-09-07 00:00:00.000',
#  'deaths_a': 0,
#  'deaths_b': 0,
#  'deaths_civilians': 2,
#  'deaths_unknown': 0,
#  'dyad_dset_id': '130',
#  'dyad_name': 'Government of Afghanistan - Civilians',
#  'dyad_new_id': 951,
#  'event_clarity': 1,
#  'geom_wkt': 'POINT (67.116647 36.700067)',
#  'gwnoa': 700,
#  'gwnob': None,
#  'high': 2,
#  'id': 488200,
#  'latitude': 36.700067,
#  'longitude': 67.116647,
#  'low': 0,
#  'number_of_sources': 2,
#  'priogrid_gid': 182655,
#  'region': 'Asia',
#  'relid': 'AFG-2023-3-951-89',
#  'side_a': 'Government of Afghanistan',
#  'side_a_dset_id': '130',
#  'side_a_new_id': 130,
#  'side_b': 'Civilians',
#  'side_b_dset_id': '9999',
#  'side_b_new_id': 1,
#  'source_article': '"Hasht e Subh Daily,2023-09-07,Unknown Gunmen Shoot Former '
#                    'Military Officer Dead in Balkh";"Kabul '
#                    'Now,2023-09-26,Nearly 200 Killed and Detained in One '
#                    'Month;  the Taliban’s Claims of Security Falter"',
#  'source_date': '2023-09-07;2023-09-26',
#  'source_headline': 'Unknown Gunmen Shoot Former Military Officer Dead in '
#                     'Balkh;Nearly 200 Killed and Detained in One Month;  the '
#                     'Taliban’s Claims of Security Falter',
#  'source_office': 'Hasht e Subh Daily;Kabul Now',
#  'source_original': 'Local sources in Balkh',
#  'type_of_violence': 3,
#  'where_coordinates': 'Mazari Sharif town',
#  'where_description': 'Kart-e-Sulh area of the seventh district of '
#                       'Mazar-e-Sharif city',
#  'where_prec': 1,
#  'year': 2023}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# In  [19]:
# Line 6:     fdsfsdfds
#
# NameError: name 'fdsfsdfds' is not defined
# ---------------------------------------------------------------------------

# %%
import pandas as pd
import arcgis

# %%
df = pd.read_csv(path)
df
# Out:
#           id                relid  year  active_year  ... high  low  gwnoa  gwnob
# 0     488200    AFG-2023-3-951-89  2023         True  ...    2    0  700.0    NaN
# 1     490237    AFG-2023-3-951-91  2023         True  ...    1    0  700.0    NaN
# 2     490241    AFG-2023-3-951-92  2023         True  ...    1    1  700.0    NaN
# 3     490851    AFG-2023-3-951-93  2023         True  ...    1    0  700.0    NaN
# 4     490852    AFG-2023-3-951-94  2023         True  ...    1    0  700.0    NaN
# ...      ...                  ...   ...          ...  ...  ...  ...    ...    ...
# 2095  493615  YEM-2023-2-14596-33  2023         True  ...    4    4    NaN    NaN
# 2096  493617  YEM-2023-2-14596-34  2023         True  ...    5    4    NaN    NaN
# 2097  493556  YEM-2023-2-14596-32  2023         True  ...    7    7    NaN    NaN
# 2098  490700   YEM-2023-2-17326-2  2023        False  ...    1    1    NaN    NaN
# 2099  493594   ETH-2023-2-17603-0  2023        False  ...    9    9    NaN    NaN
#
# [2100 rows x 49 columns]

# %%
# lets make it spatial
points = 'ConflictEvents'
points_path = arcpy.management.XYTableToPoint(table, points, 'longitude', 'latitude')

# %%
from arcgis import GIS
gis = GIS()
item = gis.content.get("85d0ca4ea1ca4b9abf0c51b9bd34de2e")
item
# Out:
# <Item title:"USA Major Cities" type:Feature Layer Collection owner:esri_dm>

# %%
df = pd.DataFrame.spatial.from_featureclass(str(points_path))

# %%
m = GIS().map("Ukraine")

# %%
df.spatial.plot(map_widget=m)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# In  [38]:
# Line 1:     df.spatial.plot(map_widget=m)
#
# File C:\Users\karimb\AppData\Local\ESRI\conda\envs\hydrorein\lib\site-packages\arcgis\features\geo\_accessor.py, in plot:
# Line 2428:  _plot_map_widget(map_widget)
#
# File C:\Users\karimb\AppData\Local\ESRI\conda\envs\hydrorein\lib\site-packages\arcgis\features\geo\_accessor.py, in _plot_map_widget:
# Line 2396:  plot(
#
# File C:\Users\karimb\AppData\Local\ESRI\conda\envs\hydrorein\lib\site-packages\arcgis\features\geo\_viz\mapping.py, in plot:
# Line 203:   fc = df.spatial.to_feature_collection(name=name)
#
# File C:\Users\karimb\AppData\Local\ESRI\conda\envs\hydrorein\lib\site-packages\arcgis\features\geo\_accessor.py, in to_feature_collection:
# Line 3639:  fs = self.__feature_set__
#
# File C:\Users\karimb\AppData\Local\ESRI\conda\envs\hydrorein\lib\site-packages\arcgis\features\geo\_accessor.py, in __feature_set__:
# Line 3313:  df = self._data.where(pd.notnull(self._data), None)
#
# File C:\Users\karimb\AppData\Local\ESRI\conda\envs\hydrorein\lib\site-packages\pandas\util\_decorators.py, in wrapper:
# Line 311:   return func(*args, **kwargs)
#
# File C:\Users\karimb\AppData\Local\ESRI\conda\envs\hydrorein\lib\site-packages\pandas\core\frame.py, in where:
# Line 10964: return super().where(cond, other, inplace, axis, level, errors, try_cast)
#
# File C:\Users\karimb\AppData\Local\ESRI\conda\envs\hydrorein\lib\site-packages\pandas\core\generic.py, in where:
# Line 9315:  return self._where(cond, other, inplace, axis, level, errors=errors)
#
# File C:\Users\karimb\AppData\Local\ESRI\conda\envs\hydrorein\lib\site-packages\pandas\core\generic.py, in _where:
# Line 9157:  new_data = self._mgr.where(
#
# File C:\Users\karimb\AppData\Local\ESRI\conda\envs\hydrorein\lib\site-packages\pandas\core\internals\managers.py, in where:
# Line 324:   return self.apply(
#
# File C:\Users\karimb\AppData\Local\ESRI\conda\envs\hydrorein\lib\site-packages\pandas\core\internals\managers.py, in apply:
# Line 304:   applied = getattr(b, f)(**kwargs)
#
# File C:\Users\karimb\AppData\Local\ESRI\conda\envs\hydrorein\lib\site-packages\pandas\core\internals\blocks.py, in where:
# Line 1379:  _catch_deprecated_value_error(err)
#
# File C:\Users\karimb\AppData\Local\ESRI\conda\envs\hydrorein\lib\site-packages\pandas\core\internals\blocks.py, in where:
# Line 1377:  res_values = arr._where(cond, other).T
#
# File C:\Users\karimb\AppData\Local\ESRI\conda\envs\hydrorein\lib\site-packages\pandas\core\arrays\_mixins.py, in _where:
# Line 381:   return self._from_backing_data(res_values)
#
# File C:\Users\karimb\AppData\Local\ESRI\conda\envs\hydrorein\lib\site-packages\pandas\core\arrays\numpy_.py, in _from_backing_data:
# Line 116:   return type(self)(arr)
#
# File C:\Users\karimb\AppData\Local\ESRI\conda\envs\hydrorein\lib\site-packages\pandas\core\arrays\string_.py, in __init__:
# Line 318:   self._validate()
#
# File C:\Users\karimb\AppData\Local\ESRI\conda\envs\hydrorein\lib\site-packages\pandas\core\arrays\string_.py, in _validate:
# Line 323:   raise ValueError("StringArray requires a sequence of strings or pandas.NA")
#
# ValueError: StringArray requires a sequence of strings or pandas.NA
# ---------------------------------------------------------------------------

# %%
from arcgis.features import FeatureLayer

# %%
fs_url = 'https://services.arcgis.com/P3ePLMYs2RVChkJx/arcgis/rest/services/Resolve_Ecoregions/FeatureServer'

layer = FeatureLayer(fs_url)
layer
# Out:
# <FeatureLayer url:"https://services.arcgis.com/P3ePLMYs2RVChkJx/arcgis/rest/services/Resolve_Ecoregions/FeatureServer">

# %%
shp_path = r'C:\Users\sigridkn\Downloads\Ecoregions2017\Ecoregions2017.shp'# path to shape file

aprx = arcpy.mp.ArcGISProject("CURRENT")
map = aprx.listMaps()[0]  # assumes data to be added to first map listed
map.addDataFromPath(shp_path)

# %%
for lyr in m.listLayers():
    print(lyr)
# Out:
# Ecoregions2017
# ConflictEvents
# World Imagery

# %%
type(lyr)
# Out:
# <class 'arcpy._mp.Layer'>

# %%
eco = m.listLayers('Ecoregions2017')[0]

# %%
sym = eco.symbology

# %%
sym
